# %%
import pandas as pd
data1=pd.read_csv("/Users/mac/Downloads/Credit_card_dataset.csv")

# %%
data1
# Out:
#      CUST_ID  BALANCE_FREQUENCY  PURCHASES     PAYMENTS  CREDIT_LIMIT  \
# 0     C10001           0.818182      95.40   201.802084        1000.0
# 1     C10002           0.909091       0.00  4103.032597        7000.0
# 2     C10003           1.000000     773.17   622.066742        7500.0
# 3     C10004           0.636364    1499.00     0.000000        7500.0
# 4     C10005           1.000000      16.00   678.334763        1200.0
# ...      ...                ...        ...          ...           ...
# 8945  C19186           1.000000     291.12   325.594462        1000.0
# 8946  C19187           1.000000     300.00   275.861322        1000.0
# 8947  C19188           0.833333     144.40    81.270775        1000.0
# 8948  C19189           0.833333       0.00    52.549959         500.0
# 8949  C19190           0.666667    1093.25    63.165404        1200.0
#
#       CASH_ADVANCE
# 0         0.000000
# 1      6442.945483
# 2         0.000000
# 3       205.788017
# 4         0.000000
# ...

# %%
data1.drop_duplicates()
# Out:
#      CUST_ID  BALANCE_FREQUENCY  PURCHASES     PAYMENTS  CREDIT_LIMIT  \
# 0     C10001           0.818182      95.40   201.802084        1000.0
# 1     C10002           0.909091       0.00  4103.032597        7000.0
# 2     C10003           1.000000     773.17   622.066742        7500.0
# 3     C10004           0.636364    1499.00     0.000000        7500.0
# 4     C10005           1.000000      16.00   678.334763        1200.0
# ...      ...                ...        ...          ...           ...
# 8945  C19186           1.000000     291.12   325.594462        1000.0
# 8946  C19187           1.000000     300.00   275.861322        1000.0
# 8947  C19188           0.833333     144.40    81.270775        1000.0
# 8948  C19189           0.833333       0.00    52.549959         500.0
# 8949  C19190           0.666667    1093.25    63.165404        1200.0
#
#       CASH_ADVANCE
# 0         0.000000
# 1      6442.945483
# 2         0.000000
# 3       205.788017
# 4         0.000000
# ...

# %%
data1.describe()
# Out:
#        BALANCE_FREQUENCY     PURCHASES      PAYMENTS  CREDIT_LIMIT  \
# count        8950.000000   8950.000000   8950.000000   8949.000000
# mean            0.877271   1003.204834   1733.143852   4494.449450
# std             0.236904   2136.634782   2895.063757   3638.815725
# min             0.000000      0.000000      0.000000     50.000000
# 25%             0.888889     39.635000    383.276166   1600.000000
# 50%             1.000000    361.280000    856.901546   3000.000000
# 75%             1.000000   1110.130000   1901.134317   6500.000000
# max             1.000000  49039.570000  50721.483360  30000.000000
#
#        CASH_ADVANCE
# count   8950.000000
# mean     978.871112
# std     2097.163877
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%     1113.821139
# max    47137.211760

# %%
data1.isnull().sum()
# Out:
# CUST_ID              0
# BALANCE_FREQUENCY    0
# PURCHASES            0
# PAYMENTS             0
# CREDIT_LIMIT         1
# CASH_ADVANCE         0
# dtype: int64

# %%
data1["CREDIT_LIMIT"].fillna(data1["CREDIT_LIMIT"].mean(), inplace=True)

# %%
data1
# Out:
#      CUST_ID  BALANCE_FREQUENCY  PURCHASES     PAYMENTS  CREDIT_LIMIT  \
# 0     C10001           0.818182      95.40   201.802084        1000.0
# 1     C10002           0.909091       0.00  4103.032597        7000.0
# 2     C10003           1.000000     773.17   622.066742        7500.0
# 3     C10004           0.636364    1499.00     0.000000        7500.0
# 4     C10005           1.000000      16.00   678.334763        1200.0
# ...      ...                ...        ...          ...           ...
# 8945  C19186           1.000000     291.12   325.594462        1000.0
# 8946  C19187           1.000000     300.00   275.861322        1000.0
# 8947  C19188           0.833333     144.40    81.270775        1000.0
# 8948  C19189           0.833333       0.00    52.549959         500.0
# 8949  C19190           0.666667    1093.25    63.165404        1200.0
#
#       CASH_ADVANCE
# 0         0.000000
# 1      6442.945483
# 2         0.000000
# 3       205.788017
# 4         0.000000
# ...

# %%
data1.isnull().sum()
# Out:
# CUST_ID              0
# BALANCE_FREQUENCY    0
# PURCHASES            0
# PAYMENTS             0
# CREDIT_LIMIT         0
# CASH_ADVANCE         0
# dtype: int64

# %%
data1.drop_duplicates()
# Out:
#      CUST_ID  BALANCE_FREQUENCY  PURCHASES     PAYMENTS  CREDIT_LIMIT  \
# 0     C10001           0.818182      95.40   201.802084        1000.0
# 1     C10002           0.909091       0.00  4103.032597        7000.0
# 2     C10003           1.000000     773.17   622.066742        7500.0
# 3     C10004           0.636364    1499.00     0.000000        7500.0
# 4     C10005           1.000000      16.00   678.334763        1200.0
# ...      ...                ...        ...          ...           ...
# 8945  C19186           1.000000     291.12   325.594462        1000.0
# 8946  C19187           1.000000     300.00   275.861322        1000.0
# 8947  C19188           0.833333     144.40    81.270775        1000.0
# 8948  C19189           0.833333       0.00    52.549959         500.0
# 8949  C19190           0.666667    1093.25    63.165404        1200.0
#
#       CASH_ADVANCE
# 0         0.000000
# 1      6442.945483
# 2         0.000000
# 3       205.788017
# 4         0.000000
# ...

# %%
data1.drop('CUST_ID',axis=1, inplace=True)
data1
# Out:
#       BALANCE_FREQUENCY  PURCHASES     PAYMENTS  CREDIT_LIMIT  CASH_ADVANCE  \
# 0              0.818182      95.40   201.802084        1000.0      0.000000
# 1              0.909091       0.00  4103.032597        7000.0   6442.945483
# 2              1.000000     773.17   622.066742        7500.0      0.000000
# 3              0.636364    1499.00     0.000000        7500.0    205.788017
# 4              1.000000      16.00   678.334763        1200.0      0.000000
# ...                 ...        ...          ...           ...           ...
# 8945           1.000000     291.12   325.594462        1000.0      0.000000
# 8946           1.000000     300.00   275.861322        1000.0      0.000000
# 8947           0.833333     144.40    81.270775        1000.0      0.000000
# 8948           0.833333       0.00    52.549959         500.0     36.558778
# 8949           0.666667    1093.25    63.165404        1200.0    127.040008
#
#       Cluster
# 0           0
# 1           0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering


features_for_clustering = ['PURCHASES', 'CREDIT_LIMIT']
X_clustering = data1[features_for_clustering]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_clustering)

linkage_matrix = linkage(X_scaled, method='ward')

plt.figure(figsize=(12, 6))
dendrogram(linkage_matrix)
plt.title('Dendrogram for Hierarchical Clustering')
plt.xlabel('Customers')
plt.ylabel('Distance')
plt.show()

num_clusters = 5
hierarchical_model = AgglomerativeClustering(n_clusters=num_clusters, affinity='euclidean', linkage='ward')
hierarchical_model.fit(X_scaled)

data1['Cluster'] = hierarchical_model.labels_

plt.figure(figsize=(10, 6))
sns.scatterplot(x='PURCHASES', y='CREDIT_LIMIT', hue='Cluster', data=data1, palette='viridis')
plt.title('Clusters based on PURCHASES and CREDIT_LIMIT')
plt.xlabel('PURCHASES')
plt.ylabel('CREDIT_LIMIT')
plt.show()
# Out:
# /Users/mac/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
km=KMeans(n_clusters=5)
km=km.fit(data1)
km.inertia_
# Out:
# /Users/mac/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 96436420218.12833

# %%
plt.plot(K,sum_of_squared_distances,'bx-')
plt.xlabel('K')
plt.ylabel('sum_of_squared_distances')
plt.title('Elbow Method For Optimal K')
plt.show()
